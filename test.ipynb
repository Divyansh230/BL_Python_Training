# %%
1+1
# Out:
# 2

# %%
class Hello:

    def __str__(self):
        return 'hello object'

    def __add__

hello=Hello()
print(hello)
# Out:
# hello object

# %%
tup=tuple([1,2,3])
print(tup)
# Out:
# (1, 2, 3)
