# %%
file=open('Demo.txt','r')
data=file.read()## return the data in the form of String
print(data)
# Out:
# Helo Buddy .
# I am Learning Python and Performing Operations and making project in Python.
# Still I have Worked on Snake Ladder Game and AddressBook Project.
# Now I am Working on File Handling in Python.

# %%
data=file.readline()
print(data)
file.close()

# %%
with open('Demo.txt','r') as f:
    data=f.read()
    print(data)
# Out:
# Helo Buddy .
# I am Learning Python and Performing Operations and making project in Python.
# Still I have Worked on Snake Ladder Game and AddressBook Project.
# Now I am Working on File Handling in Python.

# %%
with open('Demo.txt','w') as f:
    f.write('new Data')

# %%
import os
os.remove('Demo.txt')
