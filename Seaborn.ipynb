# %%
! pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in e:\bl_python_training\.venv\lib\site-packages (from seaborn) (2.4.3)
# Requirement already satisfied: pandas>=1.2 in e:\bl_python_training\.venv\lib\site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in e:\bl_python_training\.venv\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in e:\bl_python_training\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in e:\bl_python_training\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\bl_python_training\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\bl_python_training\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in e:\bl_python_training\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in e:\bl_python_training\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in e:\bl_python_training\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in e:\bl_python_training\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in e:\bl_python_training\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in e:\bl_python_training\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
## Basic Plotting with Seaborn
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.title('Scatter plot of Total Bill vs Tip')
plt.show()

# %%
## Line Plot
sns.lineplot(x='size',y='total_bill',data=tips)
plt.title('Line plot of Total Bill vs Size')
plt.show()

# %%
## Categorical Variable
sns.barplot(x='day', y='total_bill', data=tips)
plt.title('Bar plot of Total Bill vs Day')
plt.show()

# %%
## Box Plot
sns.boxenplot(x='day', y='total_bill', data=tips)
plt.title('Box plot of Total Bill vs Day')
plt.show()

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
plt.title('Violin plot of Total Bill vs Day')
plt.show()

# %%
## Histograms
sns.histplot(tips['total_bill'],bins=10,kde=True)
plt.title('Histogram of Total Bill')
plt.show()

# %%
## KDE Plot

sns.kdeplot(tips['total_bill'],fill=True)
plt.title('Kdeplot of Total Bill')
plt.show()

# %%
## Pair Plot

sns.pairplot(tips)

# %%
##Heatmap
corr=tips[['total_bill','tip','size']].corr()
sns.heatmap(corr, annot=True,cmap="coolwarm")
plt.show()
